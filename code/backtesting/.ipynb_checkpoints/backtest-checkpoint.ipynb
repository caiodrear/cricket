# %%
#----------------standard packages------------------
import numpy as np
import pandas as pd
import datetime as dt
import scipy.stats as scp
import matplotlib
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

#-----------------caio's modules---------------------
import sys, os #add code folder to sys.path
for folder in ['data_processing', 'classification_models']:
    sys.path.append(os.path.abspath('../' + folder))

from model import chrono_split_encode, cricket_model #classification models
from cricsheet_read import cricsheet_read #data processing

#---------------------load data----------------------
player_data = pd.read_csv('../../data/player_data.csv', dtype = {'match_id':str},
                           parse_dates = ['start_date']).set_index('match_id')
player_data['start_date'] = player_data['start_date'].dt.date

fe_data = pd.read_csv('../../data/fe_data.csv', dtype = {'match_id':str},
                           parse_dates = ['start_date']).set_index('match_id')
fe_data['start_date'] = fe_data['start_date'].dt.date

results = cricsheet_read()[1].drop('toss_winner', axis = 1)
results = results.join(pd.read_csv('../../data/betfair_data.csv',
                                   dtype = {'match_id':str}).set_index('match_id')).sort_index()

# %%
def backtest(test_data, bankroll_init = 100, ev_threshold = 0, prop = 0.01):

    test_data.sort_values('start_date', inplace = True)

    stake = bankroll_init*prop
    test_data['model'] = ((test_data['set_value'] > ev_threshold)*stake*
                          ((test_data['set_team'] == test_data['result'])*(test_data['set_odds']) - 1) +
                          (test_data['chase_value'] > ev_threshold)*stake*
                          ((test_data['chase_team'] == test_data['result'])*(test_data['chase_odds']) - 1))    

    test_data['back_set'] = stake*((test_data['set_team'] == test_data['result'])*(test_data['set_odds']) - 1)

    test_data['back_chase'] = stake*((test_data['chase_team'] == test_data['result'])*(test_data['chase_odds']) - 1)
    
    test_data['model_stake'] = ((test_data['set_value'] > ev_threshold)*stake +
                                (test_data['chase_value'] > ev_threshold)*stake)

    test_data['back_set_stake'] = test_data['set_odds'].notna()*stake
    test_data['back_chase_stake'] = test_data['chase_odds'].notna()*stake

    test_data_lin = test_data[['model', 'back_set', 'back_chase',
                               'model_stake', 'back_set_stake', 'back_chase_stake']].copy().reset_index(drop = True)

    #------------------------------------------------------------------

    bankroll = {'model':bankroll_init, 'back_set':bankroll_init, 'back_chase':bankroll_init}

    def date_row(date, bankroll, staking = 'exp'):
        row_dict = {}

        date_data = test_data[test_data['start_date'] == date]
        
        n_model_bets = max(len(date_data[(date_data['set_value'] > ev_threshold) |
                                          (date_data['chase_value'] > ev_threshold)]), 1)
        n_bets = max(len(date_data[~date_data.isna().any(axis = 1)]), 1)
        
        if staking == 'kelly':
            set_prop = (date_data['set_value']/(date_data['set_odds']-1)*prop)/n_model_bets
            chase_prop = date_data['chase_value']/(date_data['chase_odds']-1)*prop/n_model_bets
        else:
            set_prop = prop/n_model_bets
            chase_prop = prop/n_model_bets

        row_dict['model'] = ((date_data['set_value'] > ev_threshold)*bankroll['model']*set_prop*
                             ((date_data['set_team'] == date_data['result'])*(date_data['set_odds']) - 1) +
                             (date_data['chase_value'] > ev_threshold)*bankroll['model']*chase_prop*
                             ((date_data['chase_team'] == date_data['result'])*(date_data['chase_odds']) - 1))    

        row_dict['back_set'] = (bankroll['back_set']*(prop/n_bets)*
                                ((date_data['set_team'] == date_data['result'])*(date_data['set_odds']) - 1))

        row_dict['back_chase'] = (bankroll['back_chase']*(prop/n_bets)*
                               ((date_data['chase_team'] == date_data['result'])*(date_data['chase_odds']) - 1))
        
        row_dict['model_stake'] = ((date_data['set_value'] > ev_threshold)*bankroll['model']*set_prop +
                                   (date_data['chase_value'] > ev_threshold)*bankroll['model']*chase_prop)

        row_dict['back_set_stake'] = date_data['set_odds'].notna()*bankroll['back_set']*(prop/n_bets)
        row_dict['back_chase_stake'] = date_data['chase_odds'].notna()*bankroll['back_chase']*(prop/n_bets)

        for method in ['model', 'back_set', 'back_chase']:
            bankroll[method] += row_dict[method].sum()

        return pd.DataFrame.from_dict(row_dict), bankroll

    test_data_exp, test_data_kelly = [], []
    for date in tqdm(test_data['start_date'].unique(), desc = 'exp'): 
        row_df, bankroll = date_row(date, bankroll, 'exp')                     
        test_data_exp.append(row_df)

    test_data_exp = pd.concat(test_data_exp).reset_index(drop = True)

    for date in tqdm(test_data['start_date'].unique(), desc = 'kelly'):
        row_df, bankroll = date_row(date, bankroll, 'kelly')                     
        test_data_kelly.append(row_df)

    test_data_kelly = pd.concat(test_data_kelly).reset_index(drop = True)

    def get_metrics(test_data_method):
        
        staked = np.array(test_data_method[['model_stake', 'back_set_stake', 'back_chase_stake']].copy().sum())
        
        test_data_method = test_data_method[['model', 'back_set', 'back_chase']]

        n_bets = (test_data_method !=0 & test_data_method.notna()).sum()

        returns = np.round(np.array(test_data_method.sum())/staked*100, 2)

        t_confidence = np.round(scp.t.cdf(test_data_method.sum()/
                                          (np.sqrt(n_bets)*np.std(test_data_method, ddof = 1)), n_bets - 1)*100, 2)

        return pd.DataFrame([returns, t_confidence],
                            columns = ['model', 'back_set', 'back_chase'], index = ['returns', 't_confidence'])

    for method in [[test_data_lin, 'level staking'], [test_data_exp, str(int(prop*100)) + '% staking'],
                   [test_data_kelly, str(int(prop*100)) + '% kelly staking']]:

        method[0].cumsum().plot.line(y = ['model', 'back_set', 'back_chase'], title = method[1])
        plt.show()
        print(get_metrics(method[0]))

# %%
X_train, X_test, y_train, y_test = chrono_split_encode(player_data, '2019-05-30', encode = True)
model, test_data = cricket_model(X_train, X_test, y_train, y_test, results, algorithm = 'forest', metrics = False)
backtest(test_data, bankroll_init = 100, ev_threshold = 0.2, prop = 0.02)
# Out:
# ...
# kelly:   0%|          | 0/471 [00:00<?, ?it/s]
#                model  back_set  back_chase
# returns        37.86      6.31       -7.85
# t_confidence  100.00     94.61        0.90
#                model  back_set  back_chase
# returns        26.71      2.32       -5.39
# t_confidence  100.00     69.04        9.36
#                model  back_set  back_chase
# returns        46.47      2.32       -5.39
# t_confidence  100.00     69.04        9.36
